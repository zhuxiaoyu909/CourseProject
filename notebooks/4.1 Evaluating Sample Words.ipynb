# %% [markdown]
# # Setup Environment

# %%
from working_dir import set_working_dir

# %%
set_working_dir()
# Out:
# Current working directory: D:\Work\UIUC CS\Fall 2021\CS 410 Text Info System\project\CS410-Project

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Import libraries

# %%
import numpy as np
from word_app import create_app
import pandas as pd
from sentence_ranker import Inclusion

# %%
pd.set_option('max_colwidth', 400)

# %% [markdown]
# # Sample words

# %%
sample_words_df = pd.read_csv("data/sample_words.csv")

# %%
sample_words_df.head()
# Out:
#          word  rank  sentence_count
# 0        live   330             649
# 1      corner  1591             340
# 2     serving  2104              10
# 3  newspapers  3735              19
# 4     russell  4096              16

# %%
sample_words = sample_words_df["word"].tolist()

# %%
sample_words
# Out:
# ['live', 'corner', 'serving', 'newspapers', 'russell']

# %% [markdown]
# # Evaluating sample words

# %%
app = create_app()
# Out:
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     C:\Users\Tom zhu\AppData\Roaming\nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!

# %%
def evaluate_word(word: str):
    ranked_sentences = app.search_for_sentences(word, n_results=100)
    ranked_sentences.sort_by_difficulty()
    return ranked_sentences.to_pandas(inclusion = Inclusion.All)

# %%
print(sample_words[0])
evaluate_word(sample_words[0])
# Out:
# live
#                                                                                                                                                           Sentence  \
# 0                                                                                                                       So this is where we are going to live . ''
# 1                                                                                                                          `` But where are you going to live ? ''
# 2                                                                                                                            ` But where are you going to live ? '
# 3                                                                                                                               ` How am I to live without him ? '
# 4                                                                                                                      You must live here on the island always . '
# ...

# %%
print(sample_words[1])
evaluate_word(sample_words[1])
# Out:
# corner
#                                                                                                                                                   Sentence  \
# 0                                                                                                    "`` They were with us at the corner , '' said Will ."
# 1                                                                                                               Just raise one corner so that I may peep .
# 2                                                              "`` She is so still , I guess she is asleep , '' thought Jack , peeping round the corner ."
# 3                                                                                                  So saying he disappeared round a corner of the palace .
# 4                                                                                         "This made Ned laugh , and they all turned back to the corner ."
# ...

# %%
print(sample_words[2])
evaluate_word(sample_words[2])
# Out:
# serving
#                                                                                                                                      Sentence  \
# 0                                                                                "He believed he was serving , helping , and protecting me ."
# 1                                                            "26 Israel Hands THE wind , serving us to a desire , now hauled into the west ."
# 2                                               But no one can ever get this horse without first serving the old woman for three whole days .
# 3                                    I believe we had a nicer time than if we 'd known they were coming and been cumbered with much serving .
# 4                                                                     "Ah , fair and fatal decoration , serving as a mark for a hidden foe !"
# ...

# %%
print(sample_words[3])
evaluate_word(sample_words[3])
# Out:
# newspapers
#                                                                                                                                                  Sentence  \
# 0                                                                                        I am of the opinion it comes of reading the newspapers so much .
# 1                                                                                   The newspapers wrote about his performance in very flattering terms .
# 2                                                                                He was working in a remote district where newspapers seldom penetrated .
# 3                                                                         "asked the major a moment afterward , as the courier came in with newspapers ."
# 4                                                                                The Goblin laid the tongue on the tub in which were the old newspapers .
# ...

# %%
print(sample_words[4])
evaluate_word(sample_words[4])
# Out:
# russell
#                                                                                                                                                Sentence  \
# 0                                                                                   But Mr. Russell told him yesterday that the bank was all right . ''
# 1                                                                                    "`` Did you hear how Geordie Russell was today , Captain Jim ? ''"
# 2                                                                                    `` Miss Russell always went to her friends in town for Christmas .
# 3                                                                                  "Of course , all the Tories were over in Raymond Russell 's store ."
# 4                                                                                                          Maud Russell was not in and Carol was glad .
# ...
